# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-36edc987-b634-4ae0-8671-25a55409e3c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-36edc987-b634-4ae0-8671-25a55409e3c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving FuelConsumption.csv to FuelConsumption.csv

# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('FuelConsumption.csv')

# %%
df
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0             AS5        Z                   9.9                  6.7
# 1              M6        Z                  11.2                  7.7
# 2             AV7        Z                   6.0                  5.8
# 3             AS6        Z                  12.7                  9.1
# 4             AS6        Z                  12.1                  8.7
# ...           ...      ...                   ...                  ...
# 1062          AS6        X                  13.4                  9.8
# 1063          AS6        X                  13.2                  9.5
# 1064          AS6        X                  13.4                  9.8
# 1065          AS6        X                  12.9                  9.3
# 1066          AS6        X                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                      8.5                        33           196
# 1                      9.6                        29           221
# 2                      5.9                        48           136
# 3                     11.1                        25           255
# 4                     10.6                        27           244
# ...                    ...                       ...           ...
# 1062                  11.8                        24           271
# 1063                  11.5                        25           264
# 1064                  11.8                        24           271
# 1065                  11.3                        25           260
# 1066                  12.8                        22           294
#
# [1067 rows x 13 columns]

# %%
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %%
df.shape
# Out:
# (1067, 13)

# %%
df.isnull().sum()
# Out:
# MODELYEAR                   0
# MAKE                        0
# MODEL                       0
# VEHICLECLASS                0
# ENGINESIZE                  0
# CYLINDERS                   0
# TRANSMISSION                0
# FUELTYPE                    0
# FUELCONSUMPTION_CITY        0
# FUELCONSUMPTION_HWY         0
# FUELCONSUMPTION_COMB        0
# FUELCONSUMPTION_COMB_MPG    0
# CO2EMISSIONS                0
# dtype: int64

# %%
x = df[['ENGINESIZE']].values
y = df[['CO2EMISSIONS']]

# %% [markdown]
# **Visualization**

# %%
plt.scatter(x,y, marker='+',color='red')
plt.xlabel("ENGINESIZE")
plt.ylabel("CO2EMISSIONS")
plt.title("Prediction")
# Out:
# Text(0.5, 1.0, 'Prediction')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=1)

# %%
x_test
# Out:
# array([[3. ],
#        [1.4],
#        [2. ],
#        [2. ],
#        [4.6],
#        [3. ],
#        [2. ],
#        [1.8],
#        [3. ],
#        [2.4],
#        [2.4],
#        [3. ],
#        [2.4],
#        [5.2],
#        [2.5],
#        [2.5],
#        [1.6],
#        [4.4],
#        [3.5],
#        [2.4],
#        [6. ],
#        [2.5],
#        [3.7],
#        [3.5],
#        [3.7],
#        [3. ],
#        [1.2],
#        [5.5],
#        [1.6],
#        [2. ],
#        [3. ],
#        [5.2],
#        [3.5],
#        [5.3],
#        [4. ],
#        [5.3],
#        [6.2],
#        [1.5],
#        [4.2],
#        [3.3],
#        [3. ],
#        [6.3],
#        [2. ],
#        [3.6],
#        [3.7],
#        [2. ],
#        [1.4],
#        [1.4],
#        [2. ],
#        [3.4],
#        [1.6],
#        [5.7],
#        [4.3],
#        [6.2],
#        [2. ],
#        [3.7],
#        [2.5],
#        [5. ],
#        [3.7],
#        [1.6],
#        [2.4],
#        [2.7],
#        [2. ],
#        [2. ],
#        [2. ],
#        [1.8],
#        [3.7],
#        [3.6],
#        [2. ],
#        [1.6],
#        [2. ],
#        [2. ],
#        [3.6],
#        [3.5],
#        [5. ],
#        [6.2],
#        [2. ],
#        [6.2],
#        [2. ],
#        [3.7],
#        [6.2],
#        [1.4],
#        [5.7],
#        [5. ],
#        [2. ],
#        [6.2],
#        [3.8],
#        [3.5],
#        [2. ],
#        [3.6],
#        [5.3],
#        [4.4],
#        [2. ],
#        [3.5],
#        [2. ],
#        [2. ],
#        [5.3],
#        [6.7],
#        [2. ],
#        [4. ],
#        [2.4],
#        [6.2],
#        [2. ],
#        [3.5],
#        [1.6],
#        [4.4],
#        [1.8],
#        [5.3],
#        [1.8],
#        [2. ],
#        [2.4],
#        [6.2],
#        [5.5],
#        [4.4],
#        [5.3],
#        [3.5],
#        [2.5],
#        [2.5],
#        [5. ],
#        [2. ],
#        [3.8],
#        [4.3],
#        [2. ],
#        [3.7],
#        [2. ],
#        [2. ],
#        [5.7],
#        [5.7],
#        [4.7],
#        [2. ],
#        [2.4],
#        [1.6],
#        [3.6],
#        [3.6],
#        [5.3],
#        [4.7],
#        [5. ],
#        [1.6],
#        [5.3],
#        [2.4],
#        [1.4],
#        [2. ],
#        [2. ],
#        [1.2],
#        [4.7],
#        [2. ],
#        [5. ],
#        [5.4],
#        [5.3],
#        [3.6],
#        [2. ],
#        [3. ],
#        [5.9],
#        [5.6],
#        [3.5],
#        [2.5],
#        [3.5],
#        [6.2],
#        [1.8],
#        [2. ],
#        [1.6],
#        [3.6],
#        [4. ],
#        [1.4],
#        [3. ],
#        [5.7],
#        [2. ],
#        [3.5],
#        [5.7],
#        [3.5],
#        [3.7],
#        [4.7],
#        [4. ],
#        [1.6],
#        [5. ],
#        [3. ],
#        [6.2],
#        [3.4],
#        [1.5],
#        [6. ],
#        [4. ],
#        [5.3],
#        [3. ],
#        [1.4],
#        [3.5],
#        [3.5],
#        [2.4],
#        [3.5],
#        [3.5],
#        [1.4],
#        [2. ],
#        [1.6],
#        [2.4],
#        [6. ],
#        [4.4],
#        [3.6],
#        [3.5],
#        [3.4],
#        [5.7],
#        [4.4],
#        [3.5],
#        [3.8],
#        [3.5],
#        [3.6],
#        [3.6],
#        [2. ],
#        [1.6],
#        [3.8],
#        [2.4],
#        [3.6],
#        [1.6],
#        [3.8],
#        [3.7],
#        [2. ],
#        [3. ],
#        [6.4],
#        [2.5],
#        [4.8],
#        [4. ],
#        [1.5],
#        [1.6],
#        [2. ],
#        [3.2],
#        [3.6],
#        [6.2],
#        [3. ],
#        [4.4],
#        [2. ],
#        [3.5],
#        [3.5],
#        [3.5],
#        [1.6],
#        [1.4],
#        [5.7],
#        [5. ],
#        [2. ],
#        [1.4],
#        [3.6],
#        [5. ],
#        [5.6],
#        [4.8],
#        [2.5],
#        [2. ],
#        [6.2],
#        [5. ],
#        [3. ],
#        [1.6],
#        [3.4],
#        [2.4],
#        [3.7],
#        [5. ],
#        [3.7],
#        [3.5],
#        [5.7],
#        [1.6],
#        [3.2],
#        [5.2],
#        [4. ],
#        [5. ],
#        [3.6],
#        [3.5],
#        [3. ],
#        [4.3],
#        [5.6],
#        [1.8],
#        [3.5],
#        [2. ]])

# %%
y_test
# Out:
#       CO2EMISSIONS
# 133            274
# 340            200
# 948            196
# 704            161
# 661            320
# ...            ...
# 238            269
# 546            345
# 773            205
# 354            264
# 1041           186
#
# [267 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.predict(x_test)
# Out:
# array([[242.88082083],
#        [179.60282889],
#        [203.33207587],
#        [203.33207587],
#        [306.15881277],
#        [242.88082083],
#        [203.33207587],
#        [195.42232688],
#        [242.88082083],
#        [219.15157386],
#        [219.15157386],
#        [242.88082083],
#        [219.15157386],
#        [329.88805975],
#        [223.10644835],
#        [223.10644835],
#        [187.51257789],
#        [298.24906378],
#        [262.65519331],
#        [219.15157386],
#        [361.52705572],
#        [223.10644835],
#        [270.56494231],
#        [262.65519331],
#        [270.56494231],
#        [242.88082083],
#        [171.6930799 ],
#        [341.75268324],
#        [187.51257789],
#        [203.33207587],
#        [242.88082083],
#        [329.88805975],
#        [262.65519331],
#        [333.84293425],
#        [282.42956579],
#        [333.84293425],
#        [369.43680471],
#        [183.55770339],
#        [290.33931479],
#        [254.74544432],
#        [242.88082083],
#        [373.39167921],
#        [203.33207587],
#        [266.61006781],
#        [270.56494231],
#        [203.33207587],
#        [179.60282889],
#        [179.60282889],
#        [203.33207587],
#        [258.70031882],
#        [187.51257789],
#        [349.66243223],
#        [294.29418928],
#        [369.43680471],
#        [203.33207587],
#        [270.56494231],
#        [223.10644835],
#        [321.97831076],
#        [270.56494231],
#        [187.51257789],
#        [219.15157386],
#        [231.01619734],
#        [203.33207587],
#        [203.33207587],
#        [203.33207587],
#        [195.42232688],
#        [270.56494231],
#        [266.61006781],
#        [203.33207587],
#        [187.51257789],
#        [203.33207587],
#        [203.33207587],
#        [266.61006781],
#        [262.65519331],
#        [321.97831076],
#        [369.43680471],
#        [203.33207587],
#        [369.43680471],
#        [203.33207587],
#        [270.56494231],
#        [369.43680471],
#        [179.60282889],
#        [349.66243223],
#        [321.97831076],
#        [203.33207587],
#        [369.43680471],
#        [274.5198168 ],
#        [262.65519331],
#        [203.33207587],
#        [266.61006781],
#        [333.84293425],
#        [298.24906378],
#        [203.33207587],
#        [262.65519331],
#        [203.33207587],
#        [203.33207587],
#        [333.84293425],
#        [389.21117719],
#        [203.33207587],
#        [282.42956579],
#        [219.15157386],
#        [369.43680471],
#        [203.33207587],
#        [262.65519331],
#        [187.51257789],
#        [298.24906378],
#        [195.42232688],
#        [333.84293425],
#        [195.42232688],
#        [203.33207587],
#        [219.15157386],
#        [369.43680471],
#        [341.75268324],
#        [298.24906378],
#        [333.84293425],
#        [262.65519331],
#        [223.10644835],
#        [223.10644835],
#        [321.97831076],
#        [203.33207587],
#        [274.5198168 ],
#        [294.29418928],
#        [203.33207587],
#        [270.56494231],
#        [203.33207587],
#        [203.33207587],
#        [349.66243223],
#        [349.66243223],
#        [310.11368727],
#        [203.33207587],
#        [219.15157386],
#        [187.51257789],
#        [266.61006781],
#        [266.61006781],
#        [333.84293425],
#        [310.11368727],
#        [321.97831076],
#        [187.51257789],
#        [333.84293425],
#        [219.15157386],
#        [179.60282889],
#        [203.33207587],
#        [203.33207587],
#        [171.6930799 ],
#        [310.11368727],
#        [203.33207587],
#        [321.97831076],
#        [337.79780874],
#        [333.84293425],
#        [266.61006781],
#        [203.33207587],
#        [242.88082083],
#        [357.57218122],
#        [345.70755773],
#        [262.65519331],
#        [223.10644835],
#        [262.65519331],
#        [369.43680471],
#        [195.42232688],
#        [203.33207587],
#        [187.51257789],
#        [266.61006781],
#        [282.42956579],
#        [179.60282889],
#        [242.88082083],
#        [349.66243223],
#        [203.33207587],
#        [262.65519331],
#        [349.66243223],
#        [262.65519331],
#        [270.56494231],
#        [310.11368727],
#        [282.42956579],
#        [187.51257789],
#        [321.97831076],
#        [242.88082083],
#        [369.43680471],
#        [258.70031882],
#        [183.55770339],
#        [361.52705572],
#        [282.42956579],
#        [333.84293425],
#        [242.88082083],
#        [179.60282889],
#        [262.65519331],
#        [262.65519331],
#        [219.15157386],
#        [262.65519331],
#        [262.65519331],
#        [179.60282889],
#        [203.33207587],
#        [187.51257789],
#        [219.15157386],
#        [361.52705572],
#        [298.24906378],
#        [266.61006781],
#        [262.65519331],
#        [258.70031882],
#        [349.66243223],
#        [298.24906378],
#        [262.65519331],
#        [274.5198168 ],
#        [262.65519331],
#        [266.61006781],
#        [266.61006781],
#        [203.33207587],
#        [187.51257789],
#        [274.5198168 ],
#        [219.15157386],
#        [266.61006781],
#        [187.51257789],
#        [274.5198168 ],
#        [270.56494231],
#        [203.33207587],
#        [242.88082083],
#        [377.3465537 ],
#        [223.10644835],
#        [314.06856176],
#        [282.42956579],
#        [183.55770339],
#        [187.51257789],
#        [203.33207587],
#        [250.79056983],
#        [266.61006781],
#        [369.43680471],
#        [242.88082083],
#        [298.24906378],
#        [203.33207587],
#        [262.65519331],
#        [262.65519331],
#        [262.65519331],
#        [187.51257789],
#        [179.60282889],
#        [349.66243223],
#        [321.97831076],
#        [203.33207587],
#        [179.60282889],
#        [266.61006781],
#        [321.97831076],
#        [345.70755773],
#        [314.06856176],
#        [223.10644835],
#        [203.33207587],
#        [369.43680471],
#        [321.97831076],
#        [242.88082083],
#        [187.51257789],
#        [258.70031882],
#        [219.15157386],
#        [270.56494231],
#        [321.97831076],
#        [270.56494231],
#        [262.65519331],
#        [349.66243223],
#        [187.51257789],
#        [250.79056983],
#        [329.88805975],
#        [282.42956579],
#        [321.97831076],
#        [266.61006781],
#        [262.65519331],
#        [242.88082083],
#        [294.29418928],
#        [345.70755773],
#        [195.42232688],
#        [262.65519331],
#        [203.33207587]])

# %%
plt.plot(df['ENGINESIZE'],reg.predict(df[['CO2EMISSIONS']]))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"

# %%
plt.scatter(x,y, marker='+',color='red')
plt.xlabel("ENGINESIZE")
plt.ylabel("CO2EMISSIONS")
plt.title("PREDICTION")
plt.plot(df['ENGINESIZE'],reg.predict(df[['CO2EMISSIONS']]))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"

# %%
reg.intercept_
# Out:
# array([124.23458595])

# %%
reg.coef_
# Out:
# array([[39.54874496]])

# %%
reg.score(x_test,y_test)
# Out:
# 0.7633265438534859
